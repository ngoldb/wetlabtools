# %% [markdown]
# # Tecan Worklisting
# This Notebook converts a plate map from Twist into pipetting instructions for the Tecan Fluent using worklists (.gwl files) for cloning expression vectors. In the following cell change the path to the Twist plate map (excel file) and change the location to a directory where the worklists will be saved and execute the cell.
#
# Note that these worklists only work with the respective Method on FluentControl!

# %%
import wetlabtools

plate_map = "/Users/goldbach/plate_map_test.xlsx"
gwl_location = "/Users/goldbach"

df = wetlabtools.cloning.tecanfluent.make_cloning_worklists_from_twist(plate_map, gwl_location, cautios=False)
df
# Out:
# wrote GGA worklists to /Users/goldbach/pSHPs1111B562401IQ
# wrote GIBSON worklists to /Users/goldbach/pSHPs1111B562401IQ
#                     Product Type       Name            Plate ID Well Location  \
# 0   Gene Fragments with adapters  swRHO_124  pSHPs1111B562401IQ            A1
# 1   Gene Fragments with adapters  swRHO_136  pSHPs1111B562401IQ            B1
# 2   Gene Fragments with adapters  swRHO_148  pSHPs1111B562401IQ            C1
# 3   Gene Fragments with adapters  swRHO_160  pSHPs1111B562401IQ            D1
# 4   Gene Fragments with adapters  swRHO_172  pSHPs1111B562401IQ            E1
# 5   Gene Fragments with adapters  swRHO_184  pSHPs1111B562401IQ            F1
# 6   Gene Fragments with adapters  swRHO_196  pSHPs1111B562401IQ            G1
# 7   Gene Fragments with adapters  swRHO_208  pSHPs1111B562401IQ            H1
# 8   Gene Fragments with adapters  swRHO_125  pSHPs1111B562401IQ            A2
# 9   Gene Fragments with adapters  swRHO_137  pSHPs1111B562401IQ            B2
# 10  Gene Fragments with adapters  swRHO_149  pSHPs1111B562401IQ            C2
# 11  Gene Fragments with adapters  swRHO_161  pSHPs1111B562401IQ            D2
# 12  Gene Fragments with adapters  swRHO_173  pSHPs1111B562401IQ            E2
# 13  Gene Fragments with adapters  swRHO_185  pSHPs1111B562401IQ            F2
# 14  Gene Fragments with adapters  swRHO_197  pSHPs1111B562401IQ            G2
# 15  Gene Fragments with adapters  swRHO_209  pSHPs1111B562401IQ            H2
# 16  Gene Fragments with adapters  swRHO_126  pSHPs1111B562401IQ            A3
# 17  Gene Fragments with adapters  swRHO_138  pSHPs1111B562401IQ            B3
# 18  Gene Fragments with adapters  swRHO_150  pSHPs1111B562401IQ            C3
# 19  Gene Fragments with adapters  swRHO_162  pSHPs1111B562401IQ            D3
# 20  Gene Fragments with adapters  swRHO_174  pSHPs1111B562401IQ            E3
# 21  Gene Fragments with adapters  swRHO_186  pSHPs1111B562401IQ            F3
# 22  Gene Fragments with adapters  swRHO_198  pSHPs1111B562401IQ            G3
# 23  Gene Fragments with adapters  swRHO_210  pSHPs1111B562401IQ            H3
# 24  Gene Fragments with adapters  swRHO_127  pSHPs1111B562401IQ            A4
# 25  Gene Fragments with adapters  swRHO_139  pSHPs1111B562401IQ            B4
# 26  Gene Fragments with adapters  swRHO_151  pSHPs1111B562401IQ            C4
# 27  Gene Fragments with adapters  swRHO_163  pSHPs1111B562401IQ            D4
# 28  Gene Fragments with adapters  swRHO_175  pSHPs1111B562401IQ            E4
# 29  Gene Fragments with adapters  swRHO_187  pSHPs1111B562401IQ            F4
# 30  Gene Fragments with adapters  swRHO_199  pSHPs1111B562401IQ            G4
# 31  Gene Fragments with adapters  swRHO_211  pSHPs1111B562401IQ            H4
#
#    Cloning     Vector  src_numerical
# 0      GGA      LM670              1
# 1      GGA      LM670              2
# 2      GGA      LM670              3
# 3      GGA      LM670              4
# 4      GGA      LM670              5
# 5      GGA      LM670              6
# 6      GGA      LM670              7
# 7      GGA      LM670              8
# 8      GGA      LM627              9
# 9      GGA      LM627             10
# 10     GGA      LM627             11
# 11     GGA      LM627             12
# 12  GIBSON     PHLSEC             13
# 13  GIBSON     PHLSEC             14
# 14  GIBSON     PHLSEC             15
# 15  GIBSON     PHLSEC             16
# 16  GIBSON     PHLSEC             17
# 17  GIBSON     PHLSEC             18
# 18  GIBSON     PHLSEC             19
# 19  GIBSON     PHLSEC             20
# 20  GIBSON  PHLSEC_FC             21
# 21  GIBSON  PHLSEC_FC             22
# 22  GIBSON  PHLSEC_FC             23
# 23  GIBSON  PHLSEC_FC             24
# 24     GGA      LM670             25
# 25     GGA      LM670             26
# 26     GGA      LM670             27
# 27     GGA      LM670             28
# 28  GIBSON     PHLSEC             29
# 29  GIBSON     PHLSEC             30
# 30  GIBSON     PHLSEC             31
# 31  GIBSON     PHLSEC             32
